# %% [markdown]
# # SC2001 Lab Project 2: Djikstra's Algorithm

# %%
# Relevant imports for the project
import numpy as np
import pandas as pd
import math
import random
from random import randint
import matplotlib.pyplot as plt
import time
import heapq
import networkx as nx
np.random.seed(19)

# %% [markdown]
# ## (a) Suppose the input graph G = (V, E) is stored in an adjacency matrix and we use an array for the priority queue. Implement the Dijkstra’s algorithm using this setting and analyze its time complexity with respect to |V| and |E| both theoretically and empirically.

# %% [markdown]
# ### Theoretical Analysis

# %% [markdown]
# O(|V|²) + O(|E| × (k + |V|))

# %% [markdown]
# ### Empirical Analysis

# %% [markdown]
# For this question, let's first define a few key data structures:
# - Graph (We will make also hold adjacency list for use in future questions
# - Priority Queue implemented with an array

# %%
class Graph:
    def __init__(self, num_nodes, num_edges):
        self.num_nodes = num_nodes
        self.num_edges = num_edges
        self.adj_matrix = None
        self.adj_list = None
        
        # Check if the graph is valid
        if num_nodes * (num_nodes - 1) < num_edges:
            print(f"Impossible to generate a simple graph with {num_nodes} nodes and {num_edges} edges!")
            return None
        
        # Generate the graph
        self._generate_graph()
    
    def _generate_graph(self):
        # Generate a random directed graph with both representations. Creates a cycle to ensure connectivity.
        
        # Initialize adjacency list
        self.adj_list = [[] for _ in range(self.num_nodes)]
        existing_edges = set()
        
        # Create a simple cycle for connectivity
        for i in range(self.num_nodes):
            u = i
            v = (i + 1) % self.num_nodes  # Wrap around to form a cycle
            w = random.randint(1, 20)
            self.adj_list[u].append([v, w])
            existing_edges.add((u, v))
        
        # Add remaining random edges
        remaining_edges = self.num_edges - self.num_nodes
        while remaining_edges > 0:
            start_node = random.randint(0, self.num_nodes - 1)
            end_node = random.randint(0, self.num_nodes - 1)
            weight = random.randint(1, 20)
            
            if start_node != end_node and (start_node, end_node) not in existing_edges:
                self.adj_list[start_node].append([end_node, weight])
                existing_edges.add((start_node, end_node))
                remaining_edges -= 1
        
        # Create adjacency matrix from adjacency list
        self.adj_matrix = np.zeros((self.num_nodes, self.num_nodes), dtype=int)
        for i in range(self.num_nodes):
            for neighbor in self.adj_list[i]:
                node = neighbor[0]
                weight = neighbor[1]
                self.adj_matrix[i][node] = weight
    
    def get_matrix(self):
        return self.adj_matrix
    
    def get_list(self):
        return self.adj_list
    
    def print_graph(self):
        print("Adjacency Matrix:")
        print(self.adj_matrix)
        
        print("\nAdjacency List:")
        for i in range(self.num_nodes):
            print(f"from node {i:02d}: {self.adj_list[i]}")
    
    def visualize(self):
        G = nx.DiGraph()
        for i in range(self.num_nodes):
            G.add_node(i)
        
        for i in range(self.num_nodes):
            for neighbor in self.adj_list[i]:
                G.add_edge(i, neighbor[0], weight=neighbor[1])
        
        try:
            pos = nx.planar_layout(G)
            nx.draw(G, pos, with_labels=True)
        except nx.NetworkXException:
            print("\nGraph is not planar, using alternative representation")
            pos = nx.spring_layout(G)
            nx.draw(G, pos, with_labels=True)
        
        labels = nx.get_edge_attributes(G, 'weight')
        nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
        plt.show()

# %%
class PriorityQueueArray:
    
    def __init__(self):
        self.queue = []
    
    def is_empty(self):
        return len(self.queue) == 0
    
    def insert(self, priority, value):
        self.queue.append([priority, value])
    
    def extract_min(self):
        if self.is_empty():
            raise IndexError("Priority queue is empty")
            
        min_idx = 0
        min_priority = self.queue[0][0]
        
        # Find the element with minimum priority value
        for i in range(1, len(self.queue)):
            if self.queue[i][0] < min_priority:
                min_priority = self.queue[i][0]
                min_idx = i
        
        # Remove and return the minimum element
        min_element = self.queue.pop(min_idx)
        return min_element[1]
    
    def remove(self, value):
        for i in range(len(self.queue)):
            if self.queue[i][1] == value:
                del self.queue[i]
                return True
        return False

# %% [markdown]
# Now that we have made our fundamental data structures, lets do our implementation of Djikstra's algorithm with an array priority queue.

# %%
def dijkstra_adj_matrix_array(g, source):  
    n = len(g)
    d = [math.inf for _ in range(n)]
    pi = [None for _ in range(n)]  
    S = [0 for _ in range(n)]    
    
    d[source] = 0
    
    # Initialize priority queue with all vertices
    pq = PriorityQueueArray()
    for v in range(n):
        pq.insert(d[v], v)
    
    while not pq.is_empty():
        # Extract vertex with minimum distance estimate
        u = pq.extract_min()
        S[u] = 1 
        
        # For all vertices adjacent to u and not in S
        for v in range(n):
            if g[u][v] > 0:  # If there's an edge from u to v
                if S[v] != 1 and d[v] > d[u] + g[u][v]:
                    # Remove v from queue
                    pq.remove(v)
                    
                    # Update distance and predecessor
                    d[v] = d[u] + g[u][v]
                    pi[v] = u
                    
                    # Insert v into queue with new priority
                    pq.insert(d[v], v)
    
    return d, pi

# %% [markdown]
# Now let's run some experiments!

# %%
# Create graphs function
def make_graph(num_nodes, num_edges):
    if num_nodes * (num_nodes - 1) < num_edges:
        print(f"Impossible to generate a simple graph with {num_nodes} nodes and {num_edges} edges!")
        return None, None

    # Create adjacency list representation
    g2 = [[] for _ in range(num_nodes)]
    existing_edges = set()
    
    # Create simple cycle to guarantee strong connectivity
    for i in range(num_nodes):
        u = i
        v = (i + 1) % num_nodes  # Wrap around to form a cycle
        w = randint(1, 20)
        g2[u].append([v, w])
        existing_edges.add((u, v))
    
    remaining_edges = num_edges - num_nodes

    while remaining_edges > 0: 
        start_node = randint(0, num_nodes - 1)
        end_node = randint(0, num_nodes - 1)
        weight = randint(1, 20)
        
        if start_node != end_node and (start_node, end_node) not in existing_edges:
            g2[start_node].append([end_node, weight])
            existing_edges.add((start_node, end_node))
            remaining_edges -= 1
                
    # Create adjacency matrix from list
    g1 = np.zeros((num_nodes, num_nodes), dtype=int)
    for i in range(len(g2)):
        for neighbor in g2[i]:
            node = neighbor[0]
            weight = neighbor[1]
            g1[i][node] = weight
            
    return g1, g2

# %% [markdown]
# Now, let's make our experiment for vertices

# %%
def run_vertex_experiment():
    print("Running experiment with varying number of vertices...")
    
    # Parameters matching friend's setup
    n_vertices = range(10, 605, 5)  # From 10 to 600 with step 5
    n_repetitions = 10
    running_times = []
    
    for n in n_vertices:
        # 3*n edges for each graph
        m = min(n * (n - 1), 3 * n)
        g1, g2 = make_graph(n, m)
        
        if g1 is None:
            running_times.append(None)
            continue
            
        start_time = time.time()
        for _ in range(n_repetitions):
            source = randint(0, n - 1)  # Random source for each repetition
            d, pi = dijkstra_adj_matrix_array(g1, source)
        avg_time = (time.time() - start_time) / n_repetitions
        running_times.append(avg_time)
        
        # Print progress update
        if n % 50 == 0:
            print(f"Completed {n} vertices, average time: {avg_time:.6f} seconds")
    
    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(n_vertices, running_times, 'o-')
    plt.xlabel('Number of Vertices')
    plt.ylabel('Average Running Time (seconds)')
    plt.title('Dijkstra\'s Algorithm (Adjacency Matrix + Array Priority Queue)')
    plt.grid(True)
    plt.savefig('dijkstra_vertex_experiment.png')
    plt.show()
    
    return n_vertices, running_times

n_vertices, v_running_times = run_vertex_experiment()
# Out:
# Running experiment with varying number of vertices...
# Completed 50 vertices, average time: 0.000385 seconds
# Completed 100 vertices, average time: 0.001298 seconds
# Completed 150 vertices, average time: 0.002791 seconds
# Completed 200 vertices, average time: 0.004791 seconds
# Completed 250 vertices, average time: 0.007321 seconds
# Completed 300 vertices, average time: 0.010682 seconds
# Completed 350 vertices, average time: 0.014709 seconds
# Completed 400 vertices, average time: 0.019521 seconds
# Completed 450 vertices, average time: 0.024905 seconds
# Completed 500 vertices, average time: 0.030112 seconds
# Completed 550 vertices, average time: 0.036617 seconds
# Completed 600 vertices, average time: 0.043611 seconds

# %%
def run_vertex_experiment_normalised():
    print("Running experiment with varying number of vertices...")
    
    # Parameters matching friend's setup
    n_vertices = range(10, 605, 5)  # From 10 to 600 with step 1
    n_repetitions = 10
    running_times = []
    
    for n in n_vertices:
        # 3*n edges for each graph
        m = min(n * (n - 1), 4 * n)
        g1, g2 = make_graph(n, m)
        
        if g1 is None:
            running_times.append(None)
            continue
            
        start_time = time.time()
        for _ in range(n_repetitions):
            source = randint(0, n - 1)  # Random source for each repetition
            d, pi = dijkstra_adj_matrix_array(g1, source)
        avg_time = ((time.time() - start_time) / n_repetitions)/n**2 #normalise wiith n^2
        running_times.append(avg_time)
      
    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(n_vertices, running_times, 'o-')
    plt.xlabel('Number of Vertices')
    plt.ylabel('Average Running Time (Normalised)')
    plt.title('Dijkstra\'s Algorithm (Adjacency Matrix + Array Priority Queue)')
    plt.grid(True)
    plt.savefig('dijkstra_vertex_experiment.png')
    plt.show()
    
    return n_vertices, running_times

n_vertices, v_running_times = run_vertex_experiment_normalised()
# Out:
# Running experiment with varying number of vertices...

# %% [markdown]
# Now, let's run our experiments for the number of edges

# %%
# Experiment 2: Varying number of edges with fixed vertices
def run_edge_experiment(n=500):
    print(f"Running experiment with varying number of edges (fixed at {n} vertices)...")
    
    max_edges = n * (n - 1)  # Maximum possible edges for a directed graph

    # Generate edge counts with exponential growth (like friend's code)
    edge_list = []
    e = n  # Start with n edges (1 per vertex on average)
    while e <= max_edges:
        edge_list.append(int(e))
        e *= 1.2  # Increase by 20% each step
    
    n_repetitions = 5
    running_times = []
    edge_counts = []
    
    for m in edge_list:
        g1, g2 = make_graph(n, m)
        
        if g1 is None:
            continue
            
        start_time = time.time()
        for _ in range(n_repetitions):
            source = randint(0, n - 1)  # Random source
            d, pi = dijkstra_adj_matrix_array(g1, source)
        avg_time = (time.time() - start_time) / n_repetitions
        
        running_times.append(avg_time)
        edge_counts.append(m)
        
        # Print progress
        print(f"Completed {m} edges, average time: {avg_time:.6f} seconds")
    
    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(edge_counts, running_times, 'o-')
    plt.xlabel(f'Number of Edges (|E|) [V fixed at {n}]')
    plt.ylabel('Average Running Time (seconds)')
    plt.title('Dijkstra\'s Algorithm (Adjacency Matrix + Array Priority Queue) vs |E|')
    plt.grid(True)
    plt.savefig('dijkstra_edge_experiment.png')
    plt.show()
    
    return edge_counts, running_times


edge_counts, e_running_times = run_edge_experiment(600)
# Out:
# Running experiment with varying number of edges (fixed at 600 vertices)...
# Completed 600 edges, average time: 0.043965 seconds
# Completed 720 edges, average time: 0.042838 seconds
# Completed 864 edges, average time: 0.043059 seconds
# Completed 1036 edges, average time: 0.042933 seconds
# Completed 1244 edges, average time: 0.043569 seconds
# Completed 1492 edges, average time: 0.043635 seconds
# Completed 1791 edges, average time: 0.043484 seconds
# Completed 2149 edges, average time: 0.043945 seconds
# Completed 2579 edges, average time: 0.044130 seconds
# Completed 3095 edges, average time: 0.044583 seconds
# Completed 3715 edges, average time: 0.045223 seconds
# Completed 4458 edges, average time: 0.045338 seconds
# Completed 5349 edges, average time: 0.045992 seconds
# Completed 6419 edges, average time: 0.045962 seconds
# Completed 7703 edges, average time: 0.046819 seconds
# Completed 9244 edges, average time: 0.047285 seconds
# Completed 11093 edges, average time: 0.047784 seconds
# Completed 13311 edges, average time: 0.048497 seconds
# Completed 15973 edges, average time: 0.049171 seconds
# Completed 19168 edges, average time: 0.050199 seconds
# Completed 23002 edges, average time: 0.051570 seconds
# Completed 27603 edges, average time: 0.051541 seconds
# Completed 33123 edges, average time: 0.051906 seconds
# Completed 39748 edges, average time: 0.052634 seconds
# Completed 47698 edges, average time: 0.053450 seconds
# Completed 57237 edges, average time: 0.054145 seconds
# Completed 68685 edges, average time: 0.055091 seconds
# Completed 82422 edges, average time: 0.056258 seconds
# Completed 98906 edges, average time: 0.057386 seconds
# Completed 118688 edges, average time: 0.058698 seconds
# Completed 142425 edges, average time: 0.060957 seconds
# Completed 170910 edges, average time: 0.062357 seconds
# Completed 205093 edges, average time: 0.065123 seconds
# Completed 246111 edges, average time: 0.067145 seconds
# Completed 295334 edges, average time: 0.070575 seconds
# Completed 354400 edges, average time: 0.073232 seconds

# %%
# Convert lists to NumPy arrays if they are not already
edge_counts = np.array(edge_counts)
e_running_times = np.array(e_running_times)

# Compute log(E) values
log_E = np.log(edge_counts)
log_E_scaled = log_E / np.max(log_E) * np.max(e_running_times)

# Normalizing running time against log(E)
normalized_time_logE = e_running_times / log_E

# Plot experimental vs theoretical log(E) scaling
plt.figure(figsize=(10, 6))
plt.plot(edge_counts, e_running_times, 'o-', label="Experimental Running Time")
plt.plot(edge_counts, log_E_scaled, 's--', label="Theoretical log(E) Scaling", alpha=0.7)
plt.xlabel('Number of Edges (|E|)')
plt.ylabel('Running Time (seconds)')
plt.title("Dijkstra's Algorithm Runtime vs |E| (Experimental vs log(E))")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Well, above is unexpected. While we thought it would be independent of |E|, it seems to follow an $\mathcal{O}(\log(n))$

# %% [markdown]
# This can be explained by the overhead of memory accesses when a better path is found. When a better path is found, the remove method removes the value in the priority queue at $\mathcal{O}(|V|)$ time, which is roughly constant when |V| is constant in the above experiment. Let's denote this constant value by C.

# %% [markdown]
# When the graph is sparse, the probability that d[v] < d[u] + W(u,v) is low due the low number of candidates. However, as $|E|$ increases, there are more candidate edges that offer a better solution, resulting in the remove operation being used. <br>

# %% [markdown]
# Let T(n) denote the time taken to replace an edge (p,q) in the priority queue for fixed |V| and no. of edges n
# <br>
#
# Then, $T(n+1) = T(n) + \left(\frac{1}{\frac{n}{|V|}+1}\right)C$, where C = time taken to replace the edge in the priority queue
#
#
# $$
# T(n+1) = T(n) + \frac{|V|}{n + |V|} C
# $$
#
# Expanding recursively:
#
# $$
# T(n) = T(n-1) + \frac{|V|}{n-1+|V|} C
# $$
#
# $$
# = T(n-1) + \frac{|V|}{n-1+|V|} C
# $$
#
# $$
# = T(n-2) + \frac{|V|}{n-2+|V|} C + \frac{|V|}{n-1+|V|} C
# $$
#
# $$
# = T(n-k) + \sum_{i=1}^{k} \frac{|V|}{n-i+|V|} C
# $$
#
# Since \( n - k = |V| - 1 \), we get \( k = n - |V| + 1 \), thus:
#
# $$
# T(n) = T(|V|-1) + \sum_{i=1}^{n-|V|+1} \frac{|V|}{n+|V|-i} C
# $$
#
# $$
# = T(|V|-1) + \left( \sum_{i=1}^{n-|V|+1} \frac{|V|}{n+|V|-i} \right) C
# $$
# When we set $j=n+|V|−i,$<br>
# <br>
# When $i=1,$  $j = n+|V|-1,$<br>
# When $i = n−|V|+1,$  $j= n+|V|−(n−|V|+1) = 2|V|−1,$
# $$
# \therefore T(n) = T(|V|-1) + \left( \sum_{j=2|V|-1}^{n+|V|-1} \frac{|V|}{j} \right) C
# $$
#
# $$
# = C\cdot|V|\cdot(\ln(|E|+|V|−1)−\ln(2|V|−1)) + A
# $$
#
# $$
# = \mathcal{O}(|V|\log(|E|))
# $$
# And above matches our empirical results

# %% [markdown]
# ## (b) Suppose the input graph G = (V, E) is stored in an array of adjacency lists and we use a minimizing heap for the priority queue. Implement the Dijkstra’s algorithm using this setting and analyze its time complexity with respect to |V| and |E| both theoretically and empirically.

# %% [markdown]
# ### Theoretical Analysis

# %% [markdown]
# TODO: Add this in - Ali
# $$
# \mathcal{O}((|V| + |E|)\log{(|V|)})
# $$
#
# $$
#  O(|V| log |V| + |E|(k + log |V|))
# $$
# k = time taken for updating the queue when a better path is found

# %% [markdown]
# ### Empirical Analysis

# %% [markdown]
# Luckily for us, there already exists a library called heapq, that we can use to make our heap queue data structure. All we need to do is define our new djikstra algorithm and run some experiments

# %%
def dijkstra_adj_list_heap(adj_list, source):
    n = len(adj_list)
    
    # Initialize data structures
    d = [float('inf') for _ in range(n)]   # Distance array
    pi = [None for _ in range(n)]          # Predecessor array
    S = [0 for _ in range(n)]              # Set of visited nodes (in S)
    
    d[source] = 0
    pq = [(0, source)]  # Priority queue for (distance, vertex)
    
    # In the heap, we track the vertices that are still active
    in_heap = set([source])
    
    while pq:
        # Extract the vertex with minimum distance
        dist_u, u = heapq.heappop(pq)
        in_heap.remove(u)
        
        if S[u] == 1 or dist_u > d[u]:
            continue
        
        # Add u to S
        S[u] = 1
        
        # Relax all edges from u
        for v, weight in adj_list[u]:
            # If v is not in S and we found a shorter path
            if S[v] != 1 and d[v] > d[u] + weight:
                # Update distance and predecessor
                d[v] = d[u] + weight
                pi[v] = u
                
                # Only add v to the heap if it's not already in it
                if v not in in_heap:
                    heapq.heappush(pq, (d[v], v))
                    in_heap.add(v)
    
    return d, pi

# %% [markdown]
# Now let's run some experiments

# %%
def run_heap_vertex_experiment():
    print("Running experiment with varying number of vertices (adj list + heap)...")
    
    # Parameters
    n_vertices = range(10, 3000, 5) 
    n_repetitions = 10
    running_times = []
    
    for n in n_vertices:
        m = min(n * (n - 1), 3 * n)
        _, g2 = make_graph(n, m)  # g2 is the adjacency list
        
        if g2 is None:
            running_times.append(None)
            continue
            
        start_time = time.time()
        for _ in range(n_repetitions):
            source = randint(0, n - 1) 
            d, pi = dijkstra_adj_list_heap(g2, source)
        avg_time = (time.time() - start_time) / n_repetitions
        running_times.append(avg_time)
    
    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(n_vertices, running_times, 'o-')
    plt.xlabel('Number of Vertices (|V|)')
    plt.ylabel('Average Running Time (seconds)')
    plt.title('Dijkstra\'s Algorithm (Adjacency List + Heap Priority Queue)')
    plt.grid(True)
    plt.savefig('dijkstra_adj_list_heap_vertex_experiment.png')
    plt.show()
    
    return n_vertices, running_times
    
x, y=run_heap_vertex_experiment()
# Out:
# Running experiment with varying number of vertices (adj list + heap)...

# %%
def run_heap_vertex_experiment():
    print("Running experiment with varying number of vertices (adj list + heap)...")
    
    # Parameters
    n_vertices = range(10, 3000, 5) 
    n_repetitions = 10
    running_times = []
    
    for n in n_vertices:
        m = min(n * (n - 1), 3 * n)  # average degree ~3
        _, g2 = make_graph(n, m)  # g2 is the adjacency list
        
        if g2 is None:
            running_times.append(None)
            continue
            
        start_time = time.time()
        for _ in range(n_repetitions):
            source = randint(0, n - 1) 
            d, pi = dijkstra_adj_list_heap(g2, source)
        avg_time = (time.time() - start_time) / n_repetitions
        running_times.append(avg_time)

    # Convert to numpy arrays for easy processing
    v_vals = np.array(list(n_vertices))
    time_vals = np.array(running_times)

    # Normalize time by V log V
    norm_times = time_vals / (v_vals * np.log2(v_vals))

    # Plot raw running time
    plt.figure(figsize=(10, 6))
    plt.plot(v_vals, time_vals, 'o-', label='Measured Runtime')
    plt.xlabel('Number of Vertices (|V|)')
    plt.ylabel('Average Running Time (seconds)')
    plt.title('Dijkstra\'s Algorithm (Adjacency List + Heap Priority Queue)')
    plt.grid(True)
    plt.savefig('dijkstra_adj_list_heap_vertex_experiment.png')
    plt.show()

    # Plot normalized running time
    plt.figure(figsize=(10, 6))
    plt.plot(v_vals, norm_times, 'o-', color='green', label='Time / (V log V)')
    plt.xlabel('Number of Vertices (|V|)')
    plt.ylabel('Normalized Time (Time / V log V)')
    plt.title('Normalized Running Time of Dijkstra\'s Algorithm (Adj List + Heap)')
    plt.grid(True)
    plt.savefig('dijkstra_adj_list_heap_vertex_experiment_normalized.png')
    plt.show()
    
    return v_vals, time_vals, norm_times

# Run it
x, y, y_norm = run_heap_vertex_experiment()
# Out:
# Running experiment with varying number of vertices (adj list + heap)...

# %%
def run_heap_edge_experiment(n=800):
    print(f"Running experiment with varying number of edges (adj list + heap, fixed at {n} vertices)...")
    
    max_edges = n * (n - 1)  # Maximum possible edges for a directed graph
    
    # Generate edge counts
    edge_list = []
    e = n  # Start with n edges (1 per vertex on average)
    while e <= max_edges:  #Test up to the max edges
        edge_list.append(int(e))
        e *= 1.1  # 1.1 times growth to make points closer
    
    n_repetitions = 10
    running_times = []
    edge_counts = []
    
    for m in edge_list:
        _, g2 = make_graph(n, m)  # g2 is the adjacency list
        
        if g2 is None:
            continue
            
        start_time = time.time()
        for _ in range(n_repetitions):
            source = randint(0, n - 1)  # Random source
            d, pi = dijkstra_adj_list_heap(g2, source)
        avg_time = (time.time() - start_time) / n_repetitions
        
        running_times.append(avg_time)
        edge_counts.append(m)
        
        # Print progress
        print(f"Completed {m} edges, average time: {avg_time:.6f} seconds")
    
    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(edge_counts, running_times, 'o-')
    plt.xlabel(f'Number of Edges (|E|) [V fixed at {n}]')
    plt.ylabel('Average Running Time (seconds)')
    plt.title('Dijkstra\'s Algorithm (Adjacency List + Heap) vs |E|')
    plt.grid(True)
    plt.savefig('dijkstra_adj_list_heap_edge_experiment.png')
    plt.show()
    
    return edge_counts, running_times

_,_ = run_heap_edge_experiment(3000)
# Out:
# Running experiment with varying number of edges (adj list + heap, fixed at 3000 vertices)...
# Completed 3000 edges, average time: 0.001312 seconds
# Completed 3300 edges, average time: 0.001892 seconds
# Completed 3630 edges, average time: 0.001589 seconds
# Completed 3993 edges, average time: 0.001290 seconds
# Completed 4392 edges, average time: 0.001235 seconds
# Completed 4831 edges, average time: 0.001274 seconds
# Completed 5314 edges, average time: 0.001260 seconds
# Completed 5846 edges, average time: 0.001373 seconds
# Completed 6430 edges, average time: 0.001377 seconds
# Completed 7073 edges, average time: 0.001388 seconds
# Completed 7781 edges, average time: 0.001504 seconds
# Completed 8559 edges, average time: 0.001529 seconds
# Completed 9415 edges, average time: 0.001584 seconds
# Completed 10356 edges, average time: 0.001683 seconds
# Completed 11392 edges, average time: 0.001692 seconds
# Completed 12531 edges, average time: 0.001756 seconds
# Completed 13784 edges, average time: 0.001821 seconds
# Completed 15163 edges, average time: 0.001782 seconds
# Completed 16679 edges, average time: 0.001878 seconds
# Completed 18347 edges, average time: 0.001976 seconds
# Completed 20182 edges, average time: 0.001994 seconds
# Completed 22200 edges, average time: 0.002062 seconds
# Completed 24420 edges, average time: 0.001969 seconds
# Completed 26862 edges, average time: 0.002076 seconds
# Completed 29549 edges, average time: 0.002121 seconds
# Completed 32504 edges, average time: 0.002223 seconds
# Completed 35754 edges, average time: 0.002243 seconds
# Completed 39329 edges, average time: 0.002296 seconds
# Completed 43262 edges, average time: 0.002444 seconds
# Completed 47589 edges, average time: 0.002429 seconds
# Completed 52348 edges, average time: 0.002561 seconds
# Completed 57583 edges, average time: 0.002666 seconds
# Completed 63341 edges, average time: 0.002789 seconds
# Completed 69675 edges, average time: 0.003081 seconds
# Completed 76643 edges, average time: 0.003168 seconds
# Completed 84307 edges, average time: 0.003548 seconds
# Completed 92738 edges, average time: 0.003869 seconds
# Completed 102011 edges, average time: 0.003849 seconds
# Completed 112213 edges, average time: 0.004268 seconds
# Completed 123434 edges, average time: 0.006211 seconds
# Completed 135777 edges, average time: 0.005361 seconds
# Completed 149355 edges, average time: 0.005712 seconds
# Completed 164291 edges, average time: 0.006236 seconds
# Completed 180720 edges, average time: 0.006747 seconds
# Completed 198792 edges, average time: 0.007277 seconds
# Completed 218671 edges, average time: 0.008035 seconds
# Completed 240538 edges, average time: 0.008453 seconds
# Completed 264592 edges, average time: 0.009783 seconds
# Completed 291051 edges, average time: 0.013840 seconds
# Completed 320156 edges, average time: 0.011005 seconds
# Completed 352172 edges, average time: 0.011633 seconds
# Completed 387389 edges, average time: 0.012663 seconds
# Completed 426128 edges, average time: 0.013678 seconds
# Completed 468741 edges, average time: 0.014867 seconds
# Completed 515615 edges, average time: 0.017637 seconds
# Completed 567177 edges, average time: 0.017756 seconds
# Completed 623895 edges, average time: 0.020803 seconds
# Completed 686284 edges, average time: 0.024114 seconds
# Completed 754913 edges, average time: 0.023675 seconds
# Completed 830404 edges, average time: 0.026048 seconds
# Completed 913444 edges, average time: 0.029000 seconds
# Completed 1004789 edges, average time: 0.031273 seconds
# Completed 1105268 edges, average time: 0.032153 seconds
# Completed 1215795 edges, average time: 0.037182 seconds
# Completed 1337374 edges, average time: 0.040449 seconds
# Completed 1471112 edges, average time: 0.048286 seconds
# Completed 1618223 edges, average time: 0.047026 seconds
# Completed 1780045 edges, average time: 0.051459 seconds
# Completed 1958050 edges, average time: 0.053450 seconds
# Completed 2153855 edges, average time: 0.058827 seconds
# Completed 2369240 edges, average time: 0.063079 seconds
# Completed 2606164 edges, average time: 0.072154 seconds
# Completed 2866781 edges, average time: 0.071158 seconds
# Completed 3153459 edges, average time: 0.077140 seconds
# Completed 3468805 edges, average time: 0.079002 seconds
# Completed 3815686 edges, average time: 0.084704 seconds
# Completed 4197254 edges, average time: 0.091765 seconds
# Completed 4616980 edges, average time: 0.103713 seconds
# Completed 5078678 edges, average time: 0.106233 seconds
# Completed 5586546 edges, average time: 0.118941 seconds
# Completed 6145200 edges, average time: 0.141561 seconds
# Completed 6759720 edges, average time: 0.160605 seconds
# Completed 7435692 edges, average time: 0.179308 seconds
# Completed 8179262 edges, average time: 0.198533 seconds

# %% [markdown]
# ## (c) Compare the two implementations in (a) and (b). Discuss which implementation is better and in what circumstances.

# %% [markdown]
# One clear-cut circumstance that we can compare is for the sparsity and density of the graphs

# %%
# Will do tomorrow
